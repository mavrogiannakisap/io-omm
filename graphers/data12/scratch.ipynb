# %%
from cycler import cycler
from os import listdir, stat
from os.path import isfile, join

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import seaborn as sns
from tqdm import tqdm

# %%
# %matplotlib widget
# %matplotlib inline
# from matplotlib_inline.backend_inline import set_matplotlib_formats
#
# set_matplotlib_formats('svg', 'pdf')

# %%
def filterr(df, col, val):
    return df[df[col] == val].reset_index(drop=True)


def filterrnot(df, col, val):
    return df[df[col] != val].reset_index(drop=True)


def filterrnz(df, col):
    return filterrnot(df, col, 0)

# %%
# !for x in ssd*; do echo 'test,time' > ${x}/profile.csv; grep '>>> ' ${x}/*.err | cut -c 5- >> ${x}/profile.csv; done;
# !cat */*.out | grep test | sort | uniq > res.csv; cat */*.out | grep -v test >> res.csv;
# Out:
# zsh:1: no matches found: */*.out
# zsh:1: no matches found: */*.out

# %%
runs = pd.read_csv(f'res.csv')

# %%
def plot_line(xs, ys, label, color=None, marker=None, ax=None):
    if ax is None:
        ax = plt
    return ax.plot(xs, ys, label=label, color=color, marker=marker)


# max_vl = runs['vl'].max()
# vl_xticks = [2]
# while vl_xticks[-1] < max_vl:
#     vl_xticks.append(4*vl_xticks[-1])
# vl_xticks = np.asarray(vl_xticks)


def setup_plot(title, xlabel, ylabel, ax=None, xscale='linear', xbase=10, yscale='linear', ybase=10):
    if ax is not None:
        ax.set_title(title)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
        if xscale != 'linear':
            ax.set_xscale(xscale, base=xbase)
        if yscale != 'linear':
            ax.set_yscale(yscale, base=ybase)
        # if xticks is not None:
        #     ax.set_xticks(xticks)
        return

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    if xscale != 'linear':
        plt.xscale(xscale, base=xbase)
    if yscale != 'linear':
        plt.yscale(yscale, base=ybase)
    # if xticks is not None:
    #     plt.xticks(xticks)


def grouped_bars(df, group_name, title, yname):
    bars_per_group = len(df.columns) - 1
    x = np.arange(len(df))
    width = 1 / (bars_per_group+1)

    offset_mult = 0
    fig, ax = plt.subplots(layout='constrained')

    for col in filter(lambda x: x != group_name, df.columns):
        offset = width * offset_mult
        rects = ax.bar(x + offset, df[col], width, label=col)
        ax.bar_label(rects, padding=3)
        offset_mult += 1

    ax.set_title(title)
    ax.set_ylabel(yname)
    ax.set_xticks(x + width, df[group_name])
    ax.legend()
    plt.show()


# def grouped_hists(df, group_name, bins_name, weights_name, title='', yname=''):
#     n_bins = len(set(df[bins_name]))
#     fig, ax = plt.subplots(layout='constrained')
#     ax.hist()

# %%
for lf in [2, 8]:
    d = filterr(runs, 'lf', lf)
    # d.sort_values('vl', inplace=True)
    plt.plot(d['vl'], d['search'])
    # break
plt.xscale('log', base=2)
plt.yscale('log')
plt.show()

# %%
num_profiles = 6
profiles = [pd.read_csv(f'ssd-{i}/profile.csv')
            for i in range(1, num_profiles + 1)]

# %%
ids = list(range(1, len(profiles) + 1))
for p, id in zip(profiles, ids):
    p['id'] = id

# %%
all_data = pd.concat(profiles).reset_index()

# %%
xs = [p['test'] for p in profiles]
ws = [p['time'] for p in profiles]
labels = ids

# %%
bins = sorted(list(set(all_data['test'])))
log = False
fig, ax = plt.subplots()
ax.hist(xs, weights=ws, bins=len(bins),
        orientation='horizontal', log=log, label=labels)
plt.legend()
plt.show()

# %%
bins = sorted(list(set(all_data['test'])))
log = True
fig, ax = plt.subplots()
ax.hist(xs, weights=ws, bins=len(bins),
        orientation='horizontal', log=log, label=labels)
plt.legend()
plt.show()

# %%
res = {}
for test in tqdm(sorted(list(set(all_data['test'])))):
    tdata = filterr(all_data, 'test', test)
    sums = []
    for id in ids:
        itdata = filterr(tdata, 'id', id)
        time_spent = itdata['time'].sum()
        sums.append(time_spent)
    minv, maxv = min(sums), max(sums)
    res[test] = (maxv - minv, sums)

diffs = res
# Out:
# 100%|██████████| 53/53 [00:07<00:00,  6.66it/s]

# %%
len(diffs)
# Out:
# 53

# %%
threshold = 0
log = True
for test in diffs:
    diff, sums = diffs[test]
    if diff >= threshold:
        fig, ax = plt.subplots()
        ax.hist(ids, weights=sums, log=log,
                bins=list(range(1, num_profiles+2)))
        plt.title(f'Test: {test}')
        ax.set_xlabel("ID")
        ax.set_ylabel("Time (s)")
        print(test)
        plt.show()
# Out:
# OFileStore::Reader
# bool file_oram::o_file_store::OFileStore::IsLevelNaive(uint8_t) const
# bool file_oram::utils::Encrypt(const char*, size_t, file_oram::utils::Key, char*)
# file_oram::o_file_store::internal::ORamKey file_oram::o_file_store::OFileStore::ReadAndRemoveOramKeyOrFail(file_oram::o_file_store::Key, uint32_t)
# file_oram::o_file_store::internal::OptPart file_oram::o_file_store::internal::SuperBlock::Remove(file_oram::o_file_store::Key)
# file_oram::o_file_store::internal::Part file_oram::o_file_store::OFileStore::ExtractPartOrFail(file_oram::o_file_store::Key, uint32_t, uint8_t)
# file_oram::o_file_store::internal::PosPair file_oram::o_file_store::OFileStore::GetOldPosAndReposition(file_oram::o_file_store::internal::ORamKey, uint8_t, bool)
# file_oram::o_file_store::internal::SuperBlockMeta::SuperBlockMeta(char*)
# file_oram::path_omap::OptVal file_oram::path_omap::OMap::Read(file_oram::path_omap::Key)
# file_oram::path_omap::OptVal file_oram::path_omap::OMap::ReadAndRemove(file_oram::path_omap::Key)
# file_oram::path_omap::internal::BP file_oram::path_omap::OMap::Balance(file_oram::path_omap::internal::BP)
# file_oram::path_omap::internal::BP file_oram::path_omap::OMap::Insert(file_oram::path_omap::Key, file_oram::path_omap::Val, file_oram::path_omap::internal::BP)
# file_oram::path_omap::internal::BP file_oram::path_omap::OMap::LRotate(file_oram::path_omap::internal::BP)
# file_oram::path_omap::internal::BP file_oram::path_omap::OMap::RRotate(file_oram::path_omap::internal::BP)
# file_oram::path_omap::internal::BP file_oram::path_omap::OMap::ReadAndRemove(file_oram::path_omap::Key, file_oram::path_omap::internal::BP)
# file_oram::path_omap::internal::Block& file_oram::path_omap::OMap::FetchOrGetFromStash(file_oram::path_omap::internal::BP)
# file_oram::path_omap::internal::Block::Block(char*, size_t)
# file_oram::path_omap::internal::ORVal file_oram::path_omap::internal::Block::ToBytes(size_t)
# file_oram::path_oram::OptVal file_oram::path_oram::ORam::ReadAndRemoveFromStash(file_oram::path_oram::Key)
# file_oram::path_oram::Pos file_oram::path_oram::ORam::AddToStash(file_oram::path_oram::Key, file_oram::path_oram::Val)
# file_oram::path_oram::Pos file_oram::path_oram::ORam::PathAtLevel(file_oram::path_oram::Pos, uint32_t) const
# file_oram::path_oram::internal::Block::Block(char*, size_t)
# file_oram::path_oram::internal::Bucket::Bucket(char*, size_t)
# file_oram::path_osegtree::OptKey file_oram::path_osegtree::OSegTree::Alloc(file_oram::path_osegtree::Len)
# file_oram::path_osegtree::internal::ORVal file_oram::path_osegtree::internal::Block::ToBytes()
# int8_t file_oram::path_omap::OMap::BalanceFactor(file_oram::path_omap::internal::BP)
# size_t file_oram::o_file_store::OFileStore::NaiveORamMaxPartCount(uint8_t) const
# /Users/amin/.pyenv/versions/3.11.1/envs/playground/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   fig.canvas.print_figure(bytes_io, **kw)
# size_t file_oram::o_file_store::internal::SuperBlock::UsedSpace() const
# size_t file_oram::utils::Decrypt(const char*, size_t, file_oram::utils::Key, char*)
# static file_oram::o_file_store::ValUpdateFunc file_oram::o_file_store::OFileStore::MakeReader(file_oram::o_file_store::OptVal&)
# std::unique_ptr<char []> file_oram::path_oram::internal::Bucket::ToBytes(size_t)
# std::vector<unsigned int> file_oram::path_oram::ORam::Path(file_oram::path_oram::Pos) const
# uint8_t file_oram::o_file_store::OFileStore::LevelIdx(uint32_t) const
# uint8_t file_oram::path_omap::OMap::Height(file_oram::path_omap::internal::BP)
# virtual bool file_oram::storage::internal::MMapFileStore::Write(size_t, const string&)
# virtual grpc::Status file_oram::storage::RemoteStoreImpl::ReadMany(grpc::ServerContext*, const file_oram::storage::ReadManyRequest*, grpc::ServerWriter<file_oram::storage::EntryPart>*)
# virtual grpc::Status file_oram::storage::RemoteStoreImpl::WriteMany(grpc::ServerContext*, grpc::ServerReader<file_oram::storage::EntryPart>*, file_oram::storage::WriteManyResponse*)
# virtual std::string file_oram::storage::internal::MMapFileStore::Read(size_t)
# void file_oram::o_file_store::OFileStore::InsertPart(file_oram::o_file_store::Key, uint32_t, file_oram::o_file_store::internal::Part, uint8_t)
# void file_oram::o_file_store::OFileStore::ReadUpdate(file_oram::o_file_store::Key, const ValUpdateFunc&)
# void file_oram::o_file_store::OFileStore::SetOramKey(file_oram::o_file_store::Key, uint32_t, file_oram::o_file_store::internal::ORamKey)
# void file_oram::o_file_store::internal::SuperBlock::Add(const file_oram::o_file_store::internal::Part&)
# void file_oram::o_file_store::internal::SuperBlockMeta::ToBytes(char*)
# void file_oram::path_omap::OMap::EvictAll()
# void file_oram::path_omap::OMap::EvictORam()
# void file_oram::path_omap::OMap::Insert(file_oram::path_omap::Key, file_oram::path_omap::Val)
# void file_oram::path_oram::ORam::AddToStash(file_oram::path_oram::Pos, file_oram::path_oram::Key, file_oram::path_oram::Val)
# void file_oram::path_oram::ORam::DecryptAndAddBucket(file_oram::path_oram::Pos, const char*)
# void file_oram::path_oram::ORam::EvictAll()
# void file_oram::path_oram::ORam::FetchDummyPath()
# void file_oram::path_oram::ORam::FetchPath(file_oram::path_oram::Pos)
# void file_oram::path_oram::internal::Block::ToBytes(size_t, char*)
# void file_oram::path_osegtree::OSegTree::Free(file_oram::path_osegtree::Key, file_oram::path_osegtree::Len)
